# %%
import langchain
langchain.__version__
# Out:
# '1.2.0'

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### CREATE AN AGENT USING GEMINI

# %%
import vertexai

vertexai.init(
    project = os.getenv("GOOGLE_CLOUD_PROJECT"),
    location = os.getenv("GOOGLE_CLOUD_REGION")
)

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
# pip install -qU langchain "langchain[anthropic]"
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)
# agent
# Run the agent
agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in Houston"}]}
)
# Out:
# {'messages': [HumanMessage(content='what is the weather in Houston', additional_kwargs={}, response_metadata={}, id='81744f1b-e016-4ceb-ac4e-97e9fc45d197'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"city": "Houston"}'}, '__gemini_function_call_thought_signatures__': {'b8bbd229-da77-4569-bbd3-4759c123ebe5': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b877b-4288-71f1-928e-4fd7dcb0395e-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Houston'}, 'id': 'b8bbd229-da77-4569-bbd3-4759c123ebe5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 71, 'total_tokens': 122, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 56}}),
#   ToolMessage(content="It's always sunny in Houston!", name='get_weather', id='fad27482-f6e4-4994-adcb-75975f5f2d8c', tool_call_id='b8bbd229-da77-4569-bbd3-4759c123ebe5'),
#   AIMessage(content="It's always sunny in Houston!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b877b-4684-7da3-87d9-62ec6b2d559b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 88, 'output_tokens': 8, 'total_tokens': 96, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ### CREATE AN AGENT USING OPENAI

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
# pip install -qU langchain "langchain[anthropic]"
from langchain.agents import create_agent
# from langchain.chat_models import init_chat_model
# llm = init_chat_model("gpt-4o")

from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="o4-mini")

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)
# agent
# Run the agent
agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in Houston"}]}
)
